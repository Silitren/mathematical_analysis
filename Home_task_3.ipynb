# %%
Ответы:
    a) 12/11
    б) 14
    в) 112/27
    г) 3/2
    е) е ^ (-5/5)
    д) oo
    ж) ln(5)
    з) 1/5 - решил с помощью sympy, взял производные, а дальше что то не сообразил что делать с переменными
2. Последнее две ячейки один решен с помощью sympy, а другой обычным счетом.

# %% [markdown]
# Найти предел функции:
#
# а)limx→6x2−36x2−x−30
# б)limx→7x2−49x2−13x+42
# в∗)limx→7x+2−−−−√−x+20−−−−−√3x+9−−−−√4−2
# г)limx→03xtg4x1−cos4x
# д∗∗)limx→02–√x2sin4x(1−cos2x)32
# е)limx→∞(4x4x+3)5x27x−1
# ж∗)limx→+05x−1x
# з∗)limx→+∞ln(x2−x+1)ln(x10+x+1)

# %% [markdown]
# a)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# б)
# ![image.png](attachment:image.png)

# %% [markdown]
# г)
# ![image.png](attachment:image.png)

# %% [markdown]
# е)
# ![image.png](attachment:image.png)

# %% [markdown]
# в) Воспользовался теоремой Лопиталя, и взял производную от числителя и знаменателя
# ![image.png](attachment:image.png)

# %% [markdown]
# ж) Воспользовался теоремой Лопиталя, и взял производную от числителя и знаменателя получили 5^х * ln(5)
# ![image-2.png](attachment:image-2.png)

# %%
# з)
from sympy import limit, factorial, oo, log
from sympy.abc import x
expr = log((x ** 2) - x + 1) / log((x ** 10) + x +1)
limit_expr = limit(expr, x, oo)  
print (limit_expr)
# Out:
# 1/5

# %%
import numpy as np
factorial = np.uint64(1)
i = np.uint64()
for i in range(1,400):
    factorial *= i
    a = np.float64(i / (factorial ** (1 / i)))
    a = round (a, 10)
    print(f' Без упрощения i = {i}, {a}')

# Ориентировочно все стремится к 2,7 памяти для расчетов дальше 170! не хватает
# Out:
#  Без упрощения i = 1, 1.0
#  Без упрощения i = 2, 1.4142135624
#  Без упрощения i = 3, 1.6509636244
#  Без упрощения i = 4, 1.8072040072
#  Без упрощения i = 5, 1.9192597482
#  Без упрощения i = 6, 2.0041451296
#  Без упрощения i = 7, 2.0709966288
#  Без упрощения i = 8, 2.1252005594
#  Без упрощения i = 9, 2.1701565369
#  Без упрощения i = 10, 2.2081252132
#  Без упрощения i = 11, 2.2406732477
#  Без упрощения i = 12, 2.2689233908
#  Без упрощения i = 13, 2.2937029552
#  Без упрощения i = 14, 2.3156360189
#  Без упрощения i = 15, 2.3352028839
#  Без упрощения i = 16, 2.3527796657
#  Без упрощения i = 17, 2.3686653913
#  Без упрощения i = 18, 2.3831009974
#  Без упрощения i = 19, 2.3962829329
#  Без упрощения i = 20, 2.4083730837
#  Без упрощения i = 21, 2.4195061342
#  Без упрощения i = 22, 2.4297951111
#  Без упрощения i = 23, 2.4393356142
#  Без упрощения i = 24, 2.4482090863
#  Без упрощения i = 25, 2.4564853675
#  Без упрощения i = 26, 2.4642247119
# ...

# %%
from sympy import limit, factorial, oo
from sympy.abc import x
expr = x / (factorial(x) ** (1 / x))
limit_expr = limit(expr, x, oo)  
print (limit_expr)
# Out:
# E
