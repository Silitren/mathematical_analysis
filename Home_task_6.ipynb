# %% [markdown]
# 1)
# ![image.png](attachment:image.png)

# %% [markdown]
# 2)
# ![image.png](attachment:image.png)

# %% [markdown]
# 3)
# ![image.png](attachment:image.png)

# %% [markdown]
# 4)
# ![image.png](attachment:image.png)

# %% [markdown]
# 5) Не стал записывать вектор градиента в комплексной форме
# ![image.png](attachment:image.png)
